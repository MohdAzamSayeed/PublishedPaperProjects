# %%
import pandas as pd

# %%
data1=pd.read_csv('MathScoreTerm1.csv')
data2=pd.read_csv('DSScoreTerm1.csv')
data3=pd.read_csv('PhysicsScoreTerm1.csv')

# %%
data1.head()
# Out:
#              Name  Score  Age         Ethinicity Subject Sex  ID
# 0  AI-KYUNG CHUNG   88.0   18     White American   Maths   M   1
# 1     ALAN HARVEY   85.0   19  European American   Maths   M   2
# 2    ALAN REYNAUD   45.0   19  European American   Maths   M   3
# 3  ALBERT CENDANA   82.0   18     White American   Maths   M   4
# 4  ALBERT HOLT JR   82.0   18     White American   Maths   F   5

# %%
data2.head()
# Out:
#              Name  Score  Age         Ethinicity        Subject Sex  ID
# 0  AI-KYUNG CHUNG   82.0   18     White American  Data Structue   M   1
# 1     ALAN HARVEY   79.0   19  European American  Data Structue   M   2
# 2    ALAN REYNAUD   39.0   19  European American  Data Structue   M   3
# 3  ALBERT CENDANA   76.0   18     White American  Data Structue   M   4
# 4  ALBERT HOLT JR   76.0   18     White American  Data Structue   F   5

# %%
data1.drop(columns=['Name','Ethinicity'],inplace=True)
data1.head()
# Out:
#    Score  Age Subject Sex  ID
# 0   88.0   18   Maths   M   1
# 1   85.0   19   Maths   M   2
# 2   45.0   19   Maths   M   3
# 3   82.0   18   Maths   M   4
# 4   82.0   18   Maths   F   5

# %%
data2.drop(columns=['Name','Ethinicity'],inplace=True)
data3.drop(columns=['Name','Ethinicity'],inplace=True)

# %%
data1.isna().sum()
# Out:
# Score      3
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64

# %%
data1.fillna(0,inplace=True)
data1.isna().sum()
# Out:
# Score      0
# Age        0
# Subject    0
# Sex        0
# ID         0
# dtype: int64

# %%
# for enhancement  data1.fillna(np.mean(dataM['Score_x']),inplace=True)

# %%
data2.fillna(0,inplace=True)
data3.fillna(0,inplace=True)

# %%
dataM= data1.merge(data2, left_on='ID', right_on='ID')

# %%
dataM2=dataM.merge(data3,left_on='ID', right_on='ID')

# %%
dataM2.drop(columns=['Sex_x','Age_y','Sex_y','Age'],inplace=True)

# %%
dataM2['Sex']=dataM2['Sex'].map({'M':1,'F':2})

# %%
dataM2
# Out:
#      Score_x  Age_x Subject_x   ID  Score_y      Subject_y  Score  Subject  \
# 0       88.0     18     Maths    1     82.0  Data Structue   84.0  Physics
# 1       85.0     19     Maths    2     79.0  Data Structue   81.0  Physics
# 2       45.0     19     Maths    3     39.0  Data Structue   41.0  Physics
# 3       82.0     18     Maths    4     76.0  Data Structue   78.0  Physics
# 4       82.0     18     Maths    5     76.0  Data Structue   78.0  Physics
# 5       95.0     20     Maths    6     89.0  Data Structue   91.0  Physics
# 6       95.0     18     Maths    7     89.0  Data Structue   91.0  Physics
# 7       65.0     19     Maths    8     59.0  Data Structue   61.0  Physics
# 8       88.0     18     Maths    9     82.0  Data Structue   84.0  Physics
# 9       88.0     19     Maths   10     82.0  Data Structue   84.0  Physics
# 10      53.0     20     Maths   11     47.0  Data Structue   49.0  Physics
# ...

# %%
dataM2.to_csv(r'ScoreFinal.csv')

# %%
#for enhancement Convert ethnicity to numericalvalue
dataEth=pd.read_csv('MathScoreTerm1.csv')

# %%
dataEth['Ethinicity'].unique()
# Out:
# array(['White American', 'European American', 'Hispanic',
#        'African American'], dtype=object)

# %%
#dataEth['Ethinicity']=dataEth['Ethinicity'].map({...})
#or
pd.get_dummies(dataEth['Ethinicity']).head()
# Out:
#    African American  European American  Hispanic  White American
# 0                 0                  0         0               1
# 1                 0                  1         0               0
# 2                 0                  1         0               0
# 3                 0                  0         0               1
# 4                 0                  0         0               1
