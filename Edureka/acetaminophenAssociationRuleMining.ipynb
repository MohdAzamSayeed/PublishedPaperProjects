# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#pip install apyori
from apyori import apriori

# %%
import numpy as np
import pandas as pd
acetaminophen_data = pd.read_csv('acetaminophen.csv',header=None)
acetaminophen_data
# Out:
#                                                    0    1
# 0  acetaminophen,cellulose,cornstarch,hypromellos...  NaN
# 1  acetaminophen,citric acid,glycerin,high fructo...  NaN
# 2  acetaminophen,glyceryl stearate,hydrogenated v...  NaN
# 3  acetaminophen,hypromellose,polyethylene glycol...  NaN
# 4  acetaminophen,butylparaben,citric acid,glyceri...  NaN
# 5  acetaminophen,mannitol,cysteine hydrochloride,...
# 6  acetaminophen,citric acid,sodium starch glycol...  NaN
# 7  acetaminophen,corn syrup,starch,microcrystalli...  NaN
# 8  acetaminophen,crospovidone,edetate disodium,ge...  NaN
# 9  acetaminophen,glycerol monostearate,hydrogenat...  NaN

# %%
s= acetaminophen_data[0]
s=s.str.split(',', expand=True)
s.fillna(value=pd.np.nan, inplace=True)
print(s.iloc[0])
# Out:
# 0               acetaminophen
# 1                   cellulose
# 2                  cornstarch
# 3                hypromellose
# 4          magnesium stearate
# 5         polyethylene glycol
# 6     sodium starch glycolate
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# Name: 0, dtype: object

# %%
s.shape[1]
# Out:
# 15

# %%
records=[]
for i in range(0,s.shape[0]):
    records.append([str(s.values[i,j]) for j in range(0,s.shape[1])])

# %%
records[0]
# Out:
# ['acetaminophen',
#  'cellulose',
#  'cornstarch',
#  'hypromellose',
#  'magnesium stearate',
#  'polyethylene glycol',
#  'sodium starch glycolate',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
#association_rules =apriori(records,min_support=0.0045,min_confidence=0.2,min_lift=3,min_length=2)
#associstion_results=list(association_rules)ow to get

# %%
from apyori import apriori
association_rules =apriori(records,min_support=0.4,min_confidence=0.8,min_lift=1.5,min_length=1)
associstion_results=list(association_rules)
print(len(associstion_results))
#print(associstion_results[0])
# Out:
# 6

# %%
df = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in associstion_results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set, Items))                                   
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift']= Lift
df.sort_values(by =['Lift','Confidence'], ascending = False, inplace = True)
df.to_excel('sample.xls')
df
# Out:
#                                                 Items  \
# 0                {sodium starch glycolate, cellulose}
# 2                 {sodium starch glycolate, povidone}
# 4   {sodium starch glycolate, cellulose, acetamino...
# 6   {sodium starch glycolate, cellulose, acetamino...
# 8   {sodium starch glycolate, acetaminophen, povid...
# 10  {sodium starch glycolate, acetaminophen, povid...
# 14          {sodium starch glycolate, cellulose, nan}
# 20  {sodium starch glycolate, cellulose, acetamino...
# 22  {sodium starch glycolate, cellulose, acetamino...
# 1                {sodium starch glycolate, cellulose}
# 5   {sodium starch glycolate, cellulose, acetamino...
# 7   {sodium starch glycolate, cellulose, acetamino...
# 3                 {sodium starch glycolate, povidone}
# 9   {sodium starch glycolate, acetaminophen, povid...
# 11  {sodium starch glycolate, acetaminophen, povid...
# 13          {sodium starch glycolate, cellulose, nan}
# ...

# %%
df.to_excel('sample.xls')

# %% [markdown]
# ### use case 1 b.

# %%
ibuprofen_data = pd.read_csv('ibuprofen.csv',header=None)
ibuprofen_data
# Out:
#                                                    0
# 0  ibuprofen,acesulfame potassium,carnauba wax,co...
# 1  ibuprofen,acesulfame potassium,anhydrous citri...
# 2  ibuprofen,carnauba wax,silicon dioxide,croscar...
# 3  ibuprofen,acesulfame potassium,anhydrous citri...
# 4  ibuprofen,acesulfame potassium,carnauba wax,co...
# 5  ibuprofen,carnauba wax,sodium starch,hypromell...
# 6  ibuprofen,gelatin,polyethylene glycol,potassiu...
# 7  ibuprofen,silicon dioxide,magnesium stearate,c...
# 8  ibuprofen,carnauba wax,croscarmellose sodium,h...
# 9  ibuprofen,acesulfame potassium,carnauba wax,co...

# %%
s2= ibuprofen_data[0]
s2=s2.str.split(',', expand=True)
print(s2.iloc[0])
# Out:
# 0                      ibuprofen
# 1           acesulfame potassium
# 2                   carnauba wax
# 3      colloidal silicon dioxide
# 4                     copovidone
# 5                   hypromellose
# 6                       mannitol
# 7     medium-chain triglycerides
# 8               microcrystalline
# 9                      cellulose
# 10           polyethylene glycol
# 11              propylene glycol
# 12         sodium lauryl sulfate
# 13                     sucralose
# 14              titanium dioxide
# 15                          None
# Name: 0, dtype: object

# %%
records=[]
for i in range(0,s2.shape[0]):
    records.append([str(s2.values[i,j]) for j in range(0,s2.shape[1])])

# %%
association_rules =apriori(records,min_support=0.4,min_confidence=0.2,min_lift=1.5,min_length=1)
associstion_results=list(association_rules)
print(len(associstion_results))
#print(associstion_results[0])
# Out:
# 32

# %%
df = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in associstion_results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set, Items))                                   
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift']= Lift
df.sort_values(by =['Lift','Confidence'], ascending = False, inplace = True)
df
# Out:
#                                                  Items  \
# 3                        {cellulose, microcrystalline}
# 9                  {cellulose, microcrystalline, None}
# 11                 {cellulose, microcrystalline, None}
# 21   {carnauba wax, polyethylene glycol, hypromellose}
# 33            {cellulose, microcrystalline, ibuprofen}
# 35            {cellulose, microcrystalline, ibuprofen}
# 37     {cellulose, microcrystalline, titanium dioxide}
# 39     {cellulose, microcrystalline, titanium dioxide}
# 44   {titanium dioxide, polyethylene glycol, hyprom...
# 63      {cellulose, microcrystalline, ibuprofen, None}
# 65      {cellulose, microcrystalline, ibuprofen, None}
# 67      {cellulose, microcrystalline, ibuprofen, None}
# 69      {cellulose, microcrystalline, ibuprofen, None}
# 75   {cellulose, microcrystalline, titanium dioxide...
# 77   {cellulose, microcrystalline, titanium dioxide...
# 81   {cellulose, microcrystalline, titanium dioxide...
# ...

# %%
df.to_excel('sample2.xls')

# %% [markdown]
# ### use case 2

# %%
aspirin_data = pd.read_csv('aspirin.csv',header=None)
aspirin_data
# Out:
#                                                    0
# 0  aspirin,citric acid,sodium bicarbonate,docusat...
# 1  aspirin,docusate sodium,fumaric acid,lactose m...
# 2  aspirin,docusate sodium,fumaric acid,lactose m...
# 3         aspirin,docusate sodium,sodium bicarbonate
# 4  aspirin,caffine,docusate sodium,fumaric acid,l...
# 5  aspirin,caffine,docusate sodium,fumaric acid,l...
# 6  aspirin,carnauba wax,corn starch,hypromellose,...
# 7  aspirin,caffine,corn starch,hypromellose,micro...
# 8  aspirin,caffine,corn starch,hypromellose,micro...
# 9  aspirin,cellulose,corn starch,hypromellose,sod...

# %%
s2= aspirin_data[0]
s2=s2.str.split(',', expand=True)
print(s2.iloc[0])
# Out:
# 0               aspirin
# 1           citric acid
# 2    sodium bicarbonate
# 3       docusate sodium
# 4                  None
# 5                  None
# 6                  None
# 7                  None
# 8                  None
# 9                  None
# Name: 0, dtype: object

# %%
records=[]
for i in range(0,s2.shape[0]):
    records.append([str(s2.values[i,j]) for j in range(0,s2.shape[1])])

# %%
association_rules =apriori(records,min_support=0.4,min_confidence=0.3,min_lift=2,min_length=1)
associstion_results=list(association_rules)
print(len(associstion_results))
#print(associstion_results[0])
# Out:
# 34

# %%
df = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in associstion_results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set, Items))                                   
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift']= Lift
df.sort_values(by =['Lift','Confidence'], ascending = False, inplace = True)
df
# Out:
#                                                  Items  \
# 2                  {lactose monohydrate, fumaric acid}
# 3                  {lactose monohydrate, fumaric acid}
# 4                   {potassium chloride, fumaric acid}
# 5                   {potassium chloride, fumaric acid}
# 6            {lactose monohydrate, potassium chloride}
# 7            {lactose monohydrate, potassium chloride}
# 8            {lactose monohydrate, fumaric acid, None}
# 9            {lactose monohydrate, fumaric acid, None}
# 10           {lactose monohydrate, fumaric acid, None}
# 11           {lactose monohydrate, fumaric acid, None}
# 12            {potassium chloride, fumaric acid, None}
# 13            {potassium chloride, fumaric acid, None}
# 14            {potassium chloride, fumaric acid, None}
# 15            {potassium chloride, fumaric acid, None}
# 16     {potassium chloride, lactose monohydrate, None}
# 17     {potassium chloride, lactose monohydrate, None}
# ...

# %%
df.to_excel('sample3.xls')

# %% [markdown]
# ### use case 3

# %%
prednisolone_data = pd.read_csv('prednisolone.csv',header=None)
prednisolone_data
# Out:
#                                                    0    1
# 0  prednisolone,butylparaben,carbomer homopolymer...  NaN
# 1  prednisolone,anhydrous lactose,silicon dioxide...  NaN
# 2  prednisolone,citric acid monohydrate,silicon d...  NaN
# 3  prednisolone,citric acid monohydrate,silicon d...  NaN
# 4  prednisolone,sodium phosphate,dibasic,edetate ...  NaN
# 5  prednisolone,citric acid monohydrate,magnesium...
# 6  prednisolone,citric acid monohydrate,povidone,...  NaN
# 7  prednisolone,citric acid monohydrate,silicon d...  NaN
# 8  prednisolone,anhydrous lactose,silicon dioxide...  NaN
# 9  prednisolone,sodium phosphate,dibasic,edetate ...  NaN

# %%
s2= prednisolone_data[0]
s2=s2.str.split(',', expand=True)
s2.fillna(value=pd.np.nan, inplace=True)
print(s2.iloc[0])
# Out:
# 0                    prednisolone
# 1                    butylparaben
# 2     carbomer homopolymer type b
# 3                edetate disodium
# 4                        glycerin
# 5                   poloxamer 188
# 6                propylene glycol
# 7                           water
# 8                sodium hydroxide
# 9                       sucralose
# 10                            NaN
# 11                            NaN
# 12                            NaN
# Name: 0, dtype: object

# %%
records=[]
for i in range(0,s2.shape[0]):
    records.append([str(s2.values[i,j]) for j in range(0,s2.shape[1])])

# %%
association_rules =apriori(records,min_support=0.4,min_confidence=0.3,min_lift=2,min_length=1)
associstion_results=list(association_rules)
print(len(associstion_results))
#print(associstion_results[0])
# Out:
# 20

# %%
df = pd.DataFrame(columns=('Items','Antecedent','Consequent','Support','Confidence','Lift'))

Support =[]
Confidence = []
Lift = []
Items = []
Antecedent = []
Consequent=[]

for RelationRecord in associstion_results:
    for ordered_stat in RelationRecord.ordered_statistics:
        Support.append(RelationRecord.support)
        Items.append(RelationRecord.items)
        Antecedent.append(ordered_stat.items_base)
        Consequent.append(ordered_stat.items_add)
        Confidence.append(ordered_stat.confidence)
        Lift.append(ordered_stat.lift)

df['Items'] = list(map(set, Items))                                   
df['Antecedent'] = list(map(set, Antecedent))
df['Consequent'] = list(map(set, Consequent))
df['Support'] = Support
df['Confidence'] = Confidence
df['Lift']= Lift
df.sort_values(by =['Lift','Confidence'], ascending = False, inplace = True)
df
# Out:
#                                                  Items  \
# 2                        {cellulose, microcrystalline}
# 3                        {cellulose, microcrystalline}
# 12   {cellulose, citric acid monohydrate, microcrys...
# 14   {cellulose, citric acid monohydrate, microcrys...
# 15   {cellulose, citric acid monohydrate, microcrys...
# 17   {cellulose, citric acid monohydrate, microcrys...
# 22   {cellulose, microcrystalline, magnesium stearate}
# 23   {cellulose, microcrystalline, magnesium stearate}
# 24   {cellulose, microcrystalline, magnesium stearate}
# 25   {cellulose, microcrystalline, magnesium stearate}
# 26         {cellulose, microcrystalline, prednisolone}
# 27         {cellulose, microcrystalline, prednisolone}
# 28         {cellulose, microcrystalline, prednisolone}
# 29         {cellulose, microcrystalline, prednisolone}
# 46   {cellulose, citric acid monohydrate, magnesium...
# 48   {cellulose, citric acid monohydrate, magnesium...
# ...

# %%
df.to_excel('sample4.xls')
